# %%
import matplotlib.pyplot as plt

# Your data
train_loss = [0.266, 0.089, 0.075, 0.065, 0.056, 0.055, 0.052, 0.040, 0.039, 0.037,
              0.030, 0.032, 0.041, 0.030, 0.027, 0.026, 0.025, 0.025, 0.022, 0.021]

val_loss = [0.151, 0.137, 0.119, 0.127, 0.131, 0.131, 0.136, 0.141, 0.150, 0.172,
            0.193, 0.217, 0.194, 0.216, 0.236, 0.239, 0.242, 0.255, 0.286, 0.262]

epochs = list(range(1, 21))

# Plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, label='Training')
plt.plot(epochs, val_loss, label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Losses vs over Epochs (Training_Samples=100)')
plt.legend()
plt.grid(True)
plt.show()
